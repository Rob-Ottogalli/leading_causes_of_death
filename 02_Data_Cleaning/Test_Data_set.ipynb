# %%
import pandas as pd
import json
import numpy as np

# %%
year_2013_df = pd.read_csv("../01_Raw_Data/28_3144_compressed_2013_data.csv/2013_data.csv")
with open("../01_Raw_Data/2013_codes.json", "r") as f_open:
    code_maps_2013 = json.load(f_open)
# Out:
# C:\Users\Rob-Desktop\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (39,40,41,42,43,60,61,62,63,64,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
year_2013_df.head()
# Out:
#    resident_status  education_1989_revision  education_2003_revision  \
# 0                1                     15.0                      NaN
# 1                1                     12.0                      NaN
# 2                2                     17.0                      NaN
# 3                1                     99.0                      NaN
# 4                1                     12.0                      NaN
#
#    education_reporting_flag  month_of_death sex  detail_age_type  detail_age  \
# 0                         0               1   M                1          90
# 1                         0               1   F                1          80
# 2                         0               1   M                1          73
# 3                         0               1   M                1          78
# 4                         0               1   F                1          83
#
#    age_substitution_flag  age_recode_52            ...              \
# ...

# %%
gender_month_2013_df = year_2013_df[["sex", "month_of_death"]]
gender_month_2013_df.head()
# Out:
#   sex  month_of_death
# 0   M               1
# 1   F               1
# 2   M               1
# 3   M               1
# 4   F               1

# %%
gender_month_2013_df.to_csv("gender_month_2013.csv")
