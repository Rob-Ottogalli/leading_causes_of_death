# %%
import pandas as pd
import json
import numpy as np

# %%
#Change filepath '01_Raw_Data/2014_data.csv' when running the code on local machine
year_2014_df = pd.read_csv('01_Raw_Data/2014_data.csv', low_memory=False)
with open("01_Raw_Data/2014_codes.json", "r") as f_open:
    code_maps_2014 = json.load(f_open)



# year_2014_df = pd.read_csv('01_Raw_Data/28_3144_compressed_2014_data.csv/2014_data.csv')
# year_2015_df = pd.read_csv('01_Raw_Data/28_3144_compressed_2015_data.csv/2015_data.csv')

# %%
#Change dtypes for '358_cause_recode'
year_2014_df['358_cause_recode'] = year_2014_df['358_cause_recode'].astype(dtype=np.int64)

# %%
#year_2014_df

# %%
#Check dytpes
# year_2014_df.dtypes

# %%
#Drop irrelavent columns 
year_2014_df_2 = year_2014_df.drop(columns=['resident_status', 'education_1989_revision', 'age_recode_52', 'age_recode_12', 'education_reporting_flag', 'age_substitution_flag', 'place_of_death_and_decedents_status', 'current_data_year', 'injury_at_work', 'method_of_disposition', 'autopsy', 'activity_code', 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_', 'icd_code_10th_revision', 'race', 'bridged_race_flag', 'race_imputation_flag', 'race_recode_3', 'race_recode_5', 'hispanic_origin', 'hispanic_originrace_recode', 'detail_age_type', 'manner_of_death', 'number_of_entity_axis_conditions', 'entity_condition_1', 'entity_condition_2', 'entity_condition_3', 'entity_condition_4', 'entity_condition_5', 'entity_condition_6', 'entity_condition_7', 'entity_condition_8', 'entity_condition_9', 'entity_condition_10', 'entity_condition_11', 'entity_condition_12', 'entity_condition_13', 'entity_condition_14', 'entity_condition_15', 'entity_condition_16', 'entity_condition_17', 'entity_condition_18', 'entity_condition_19', 'entity_condition_20', 'number_of_record_axis_conditions', 'record_condition_1', 'record_condition_2', 'record_condition_3', 'record_condition_4', 'record_condition_5', 'record_condition_6', 'record_condition_7', 'record_condition_8', 'record_condition_9', 'record_condition_10', 'record_condition_11', 'record_condition_12', 'record_condition_13', 'record_condition_14', 'record_condition_15', 'record_condition_16', 'record_condition_17', 'record_condition_18', 'record_condition_19', 'record_condition_20'])

# %%
# Check Dtypes of new dataframe
# year_2014_df_2.dtypes

# %%
#Find NAN for every column
# year_2014_df_2['month_of_death'].unique()

# %%
#Drop NAN from 2003 education
year_2014_df_2 = year_2014_df_2.dropna(subset=['education_2003_revision'])
year_2014_df_2
# Out:
#          education_2003_revision  month_of_death sex  detail_age  \
# 0                            2.0               1   M          87
# 1                            2.0               1   M          58
# 2                            7.0               1   F          75
# 3                            6.0               1   M          74
# 4                            3.0               1   M          64
# 5                            5.0               1   F          93
# 6                            4.0               1   M          82
# 7                            4.0               1   M          55
# 8                            3.0               1   F          86
# 9                            3.0               1   M          23
# 10                           3.0               1   F          79
# 11                           2.0               1   M          86
# 12                           4.0               1   F          85
# 13                           3.0               1   F          84
# 14                           3.0               1   F          66
# 15                           4.0               1   F          70
# 16                           6.0               1   F          92
# 17                           5.0               1   F          82
# 18                           1.0               1   M          83
# 19                           3.0               1   F          84
# 20                           3.0               1   M          80
# 21                           8.0               1   M          66
# 22                           3.0               1   F          73
# 23                           7.0               1   F          51
# 24                           4.0               1   M          20
# 25                           7.0               1   M          45
# 26                           7.0               1   M          71
# 27                           3.0               1   F          46
# 28                           2.0               1   M          78
# 29                           2.0               1   M          72
# ...                          ...             ...  ..         ...
# 2631141                      1.0              12   M          69
# 2631142                      9.0              12   M          61
# 2631143                      9.0              11   M          66
# 2631144                      9.0              12   M          58
# 2631145                      9.0               7   M          45
# 2631146                      6.0              12   M          73
# 2631147                      1.0              12   F          21
# 2631148                      1.0              12   M           6
# 2631149                      9.0              12   F          68
# 2631150                      9.0              12   M          66
# 2631151                      1.0              11   M          55
# 2631152                      1.0              11   M          85
# 2631153                      9.0              12   M          57
# 2631154                      9.0              12   M          73
# 2631155                      1.0              12   M           3
# 2631156                      1.0               9   F           3
# 2631157                      9.0              12   M          61
# 2631158                      9.0              11   F          90
# 2631159                      4.0              11   M          85
# 2631160                      1.0              12   M           2
# 2631161                      9.0              12   M          90
# 2631162                      9.0              12   F          85
# 2631163                      1.0              11   M          79
# 2631164                      9.0              12   M          67
# 2631165                      9.0              12   M          54
# 2631166                      6.0              12   M          84
# 2631167                      9.0              12   F          74
# 2631168                      1.0              12   M           7
# 2631169                      9.0               2   M          49
# 2631170                      1.0               5   M          39
#
#          age_recode_27  infant_age_recode_22 marital_status  \
# 0                   23                   NaN              M
# 1                   17                   NaN              D
# 2                   21                   NaN              W
# 3                   20                   NaN              D
# 4                   18                   NaN              D
# 5                   24                   NaN              W
# 6                   22                   NaN              M
# 7                   17                   NaN              S
# 8                   23                   NaN              W
# 9                   10                   NaN              S
# 10                  21                   NaN              W
# 11                  23                   NaN              W
# 12                  23                   NaN              W
# 13                  22                   NaN              W
# 14                  19                   NaN              D
# 15                  20                   NaN              M
# 16                  24                   NaN              W
# 17                  22                   NaN              W
# 18                  22                   NaN              M
# 19                  22                   NaN              W
# 20                  22                   NaN              M
# 21                  19                   NaN              M
# 22                  20                   NaN              W
# 23                  16                   NaN              M
# 24                  10                   NaN              S
# 25                  15                   NaN              M
# 26                  20                   NaN              M
# 27                  15                   NaN              D
# 28                  21                   NaN              M
# 29                  20                   NaN              W
# ...                ...                   ...            ...
# 2631141             19                   NaN              U
# 2631142             18                   NaN              U
# 2631143             19                   NaN              W
# 2631144             17                   NaN              U
# 2631145             15                   NaN              U
# 2631146             20                   NaN              S
# 2631147              1                   2.0              S
# 2631148              1                   2.0              S
# 2631149             19                   NaN              S
# 2631150             19                   NaN              U
# 2631151             17                   NaN              M
# 2631152             23                   NaN              D
# 2631153             17                   NaN              U
# 2631154             20                   NaN              U
# 2631155              1                   5.0              S
# 2631156              1                   2.0              S
# 2631157             18                   NaN              S
# 2631158             24                   NaN              U
# 2631159             23                   NaN              S
# 2631160              1                   2.0              S
# 2631161             24                   NaN              U
# 2631162             23                   NaN              U
# 2631163             21                   NaN              S
# 2631164             19                   NaN              U
# 2631165             16                   NaN              U
# 2631166             22                   NaN              S
# 2631167             20                   NaN              S
# 2631168              1                   1.0              S
# 2631169             15                   NaN              U
# 2631170              1                   1.0              S
#
#          day_of_week_of_death  358_cause_recode  113_cause_recode  \
# 0                           4               238                70
# 1                           3               214                62
# 2                           2               267                86
# 3                           1               228                68
# 4                           2               214                62
# 5                           4               280               111
# 6                           6               215                63
# 7                           6               214                62
# 8                           6               175               111
# 9                           4               429               125
# 10                          2               225                68
# 11                          3               188                51
# 12                          3               225                68
# 13                          4                93                27
# 14                          6                93                27
# 15                          4               215                63
# 16                          2               228                68
# 17                          5               215                63
# 18                          4               267                86
# 19                          1               129                39
# 20                          4               215                63
# 21                          7               113                33
# 22                          5               211                59
# 23                          4               104                29
# 24                          6               429               125
# 25                          1               429               125
# 26                          4               211                59
# 27                          6               298                94
# 28                          1                81                23
# 29                          4               379               110
# ...                       ...               ...               ...
# 2631141                     3               436               129
# 2631142                     2                77                21
# 2631143                     1               211                59
# 2631144                     4               214                62
# 2631145                     1               379               110
# 2631146                     1                93                27
# 2631147                     6               363               108
# 2631148                     2               358               108
# 2631149                     4                93                27
# 2631150                     2               214                62
# 2631151                     6               122                36
# 2631152                     2               159                46
# 2631153                     6               379               110
# 2631154                     7               215                63
# 2631155                     5               364               108
# 2631156                     2               358               108
# 2631157                     7               215                63
# 2631158                     7               215                63
# 2631159                     1               215                63
# 2631160                     7               358               108
# 2631161                     1               215                63
# 2631162                     6               175               111
# 2631163                     1               215                63
# 2631164                     3               159                46
# 2631165                     5               257                78
# 2631166                     2               207                56
# 2631167                     7               215                63
# 2631168                     4               358               108
# 2631169                     1               214                62
# 2631170                     2               364               108
#
#          130_infant_cause_recode  39_cause_recode
# 0                            NaN               24
# 1                            NaN               21
# 2                            NaN               28
# 3                            NaN               22
# 4                            NaN               21
# 5                            NaN               37
# 6                            NaN               21
# 7                            NaN               21
# 8                            NaN               37
# 9                            NaN               40
# 10                           NaN               22
# 11                           NaN               37
# 12                           NaN               22
# 13                           NaN                8
# 14                           NaN                8
# 15                           NaN               21
# 16                           NaN               22
# 17                           NaN               21
# 18                           NaN               28
# 19                           NaN               13
# 20                           NaN               21
# 21                           NaN               11
# 22                           NaN               21
# 23                           NaN                9
# 24                           NaN               40
# 25                           NaN               40
# 26                           NaN               21
# 27                           NaN               30
# 28                           NaN                6
# 29                           NaN               36
# ...                          ...              ...
# 2631141                      NaN               41
# 2631142                      NaN               15
# 2631143                      NaN               21
# 2631144                      NaN               21
# 2631145                      NaN               36
# 2631146                      NaN                8
# 2631147                    106.0               33
# 2631148                     89.0               33
# 2631149                      NaN                8
# 2631150                      NaN               21
# 2631151                      NaN               15
# 2631152                      NaN               16
# 2631153                      NaN               36
# 2631154                      NaN               21
# 2631155                    117.0               33
# 2631156                     89.0               33
# 2631157                      NaN               21
# 2631158                      NaN               21
# 2631159                      NaN               21
# 2631160                     89.0               33
# 2631161                      NaN               21
# 2631162                      NaN               37
# 2631163                      NaN               21
# 2631164                      NaN               16
# 2631165                      NaN               27
# 2631166                      NaN               20
# 2631167                      NaN               21
# 2631168                     89.0               33
# 2631169                      NaN               21
# 2631170                    117.0               33
#
# [2389564 rows x 12 columns]

# %%
# Create new column for seasons 
# Bin into seasons 
size_bins = [0, 3, 6, 9, 12]
group_names = ["Winter", "Spring", "Summer", "Fall"]

# add season bins columns & row Labels
year_2014_df_2["Seasons"] = pd.cut(year_2014_df_2["month_of_death"], size_bins, labels=group_names)
year_2014_df_2["Seasons"] 
year_2014_df_2
# Out:
#          education_2003_revision  month_of_death sex  detail_age  \
# 0                            2.0               1   M          87
# 1                            2.0               1   M          58
# 2                            7.0               1   F          75
# 3                            6.0               1   M          74
# 4                            3.0               1   M          64
# 5                            5.0               1   F          93
# 6                            4.0               1   M          82
# 7                            4.0               1   M          55
# 8                            3.0               1   F          86
# 9                            3.0               1   M          23
# 10                           3.0               1   F          79
# 11                           2.0               1   M          86
# 12                           4.0               1   F          85
# 13                           3.0               1   F          84
# 14                           3.0               1   F          66
# 15                           4.0               1   F          70
# 16                           6.0               1   F          92
# 17                           5.0               1   F          82
# 18                           1.0               1   M          83
# 19                           3.0               1   F          84
# 20                           3.0               1   M          80
# 21                           8.0               1   M          66
# 22                           3.0               1   F          73
# 23                           7.0               1   F          51
# 24                           4.0               1   M          20
# 25                           7.0               1   M          45
# 26                           7.0               1   M          71
# 27                           3.0               1   F          46
# 28                           2.0               1   M          78
# 29                           2.0               1   M          72
# ...                          ...             ...  ..         ...
# 2631141                      1.0              12   M          69
# 2631142                      9.0              12   M          61
# 2631143                      9.0              11   M          66
# 2631144                      9.0              12   M          58
# 2631145                      9.0               7   M          45
# 2631146                      6.0              12   M          73
# 2631147                      1.0              12   F          21
# 2631148                      1.0              12   M           6
# 2631149                      9.0              12   F          68
# 2631150                      9.0              12   M          66
# 2631151                      1.0              11   M          55
# 2631152                      1.0              11   M          85
# 2631153                      9.0              12   M          57
# 2631154                      9.0              12   M          73
# 2631155                      1.0              12   M           3
# 2631156                      1.0               9   F           3
# 2631157                      9.0              12   M          61
# 2631158                      9.0              11   F          90
# 2631159                      4.0              11   M          85
# 2631160                      1.0              12   M           2
# 2631161                      9.0              12   M          90
# 2631162                      9.0              12   F          85
# 2631163                      1.0              11   M          79
# 2631164                      9.0              12   M          67
# 2631165                      9.0              12   M          54
# 2631166                      6.0              12   M          84
# 2631167                      9.0              12   F          74
# 2631168                      1.0              12   M           7
# 2631169                      9.0               2   M          49
# 2631170                      1.0               5   M          39
#
#          age_recode_27  infant_age_recode_22 marital_status  \
# 0                   23                   NaN              M
# 1                   17                   NaN              D
# 2                   21                   NaN              W
# 3                   20                   NaN              D
# 4                   18                   NaN              D
# 5                   24                   NaN              W
# 6                   22                   NaN              M
# 7                   17                   NaN              S
# 8                   23                   NaN              W
# 9                   10                   NaN              S
# 10                  21                   NaN              W
# 11                  23                   NaN              W
# 12                  23                   NaN              W
# 13                  22                   NaN              W
# 14                  19                   NaN              D
# 15                  20                   NaN              M
# 16                  24                   NaN              W
# 17                  22                   NaN              W
# 18                  22                   NaN              M
# 19                  22                   NaN              W
# 20                  22                   NaN              M
# 21                  19                   NaN              M
# 22                  20                   NaN              W
# 23                  16                   NaN              M
# 24                  10                   NaN              S
# 25                  15                   NaN              M
# 26                  20                   NaN              M
# 27                  15                   NaN              D
# 28                  21                   NaN              M
# 29                  20                   NaN              W
# ...                ...                   ...            ...
# 2631141             19                   NaN              U
# 2631142             18                   NaN              U
# 2631143             19                   NaN              W
# 2631144             17                   NaN              U
# 2631145             15                   NaN              U
# 2631146             20                   NaN              S
# 2631147              1                   2.0              S
# 2631148              1                   2.0              S
# 2631149             19                   NaN              S
# 2631150             19                   NaN              U
# 2631151             17                   NaN              M
# 2631152             23                   NaN              D
# 2631153             17                   NaN              U
# 2631154             20                   NaN              U
# 2631155              1                   5.0              S
# 2631156              1                   2.0              S
# 2631157             18                   NaN              S
# 2631158             24                   NaN              U
# 2631159             23                   NaN              S
# 2631160              1                   2.0              S
# 2631161             24                   NaN              U
# 2631162             23                   NaN              U
# 2631163             21                   NaN              S
# 2631164             19                   NaN              U
# 2631165             16                   NaN              U
# 2631166             22                   NaN              S
# 2631167             20                   NaN              S
# 2631168              1                   1.0              S
# 2631169             15                   NaN              U
# 2631170              1                   1.0              S
#
#          day_of_week_of_death  358_cause_recode  113_cause_recode  \
# 0                           4               238                70
# 1                           3               214                62
# 2                           2               267                86
# 3                           1               228                68
# 4                           2               214                62
# 5                           4               280               111
# 6                           6               215                63
# 7                           6               214                62
# 8                           6               175               111
# 9                           4               429               125
# 10                          2               225                68
# 11                          3               188                51
# 12                          3               225                68
# 13                          4                93                27
# 14                          6                93                27
# 15                          4               215                63
# 16                          2               228                68
# 17                          5               215                63
# 18                          4               267                86
# 19                          1               129                39
# 20                          4               215                63
# 21                          7               113                33
# 22                          5               211                59
# 23                          4               104                29
# 24                          6               429               125
# 25                          1               429               125
# 26                          4               211                59
# 27                          6               298                94
# 28                          1                81                23
# 29                          4               379               110
# ...                       ...               ...               ...
# 2631141                     3               436               129
# 2631142                     2                77                21
# 2631143                     1               211                59
# 2631144                     4               214                62
# 2631145                     1               379               110
# 2631146                     1                93                27
# 2631147                     6               363               108
# 2631148                     2               358               108
# 2631149                     4                93                27
# 2631150                     2               214                62
# 2631151                     6               122                36
# 2631152                     2               159                46
# 2631153                     6               379               110
# 2631154                     7               215                63
# 2631155                     5               364               108
# 2631156                     2               358               108
# 2631157                     7               215                63
# 2631158                     7               215                63
# 2631159                     1               215                63
# 2631160                     7               358               108
# 2631161                     1               215                63
# 2631162                     6               175               111
# 2631163                     1               215                63
# 2631164                     3               159                46
# 2631165                     5               257                78
# 2631166                     2               207                56
# 2631167                     7               215                63
# 2631168                     4               358               108
# 2631169                     1               214                62
# 2631170                     2               364               108
#
#          130_infant_cause_recode  39_cause_recode Seasons
# 0                            NaN               24  Winter
# 1                            NaN               21  Winter
# 2                            NaN               28  Winter
# 3                            NaN               22  Winter
# 4                            NaN               21  Winter
# 5                            NaN               37  Winter
# 6                            NaN               21  Winter
# 7                            NaN               21  Winter
# 8                            NaN               37  Winter
# 9                            NaN               40  Winter
# 10                           NaN               22  Winter
# 11                           NaN               37  Winter
# 12                           NaN               22  Winter
# 13                           NaN                8  Winter
# 14                           NaN                8  Winter
# 15                           NaN               21  Winter
# 16                           NaN               22  Winter
# 17                           NaN               21  Winter
# 18                           NaN               28  Winter
# 19                           NaN               13  Winter
# 20                           NaN               21  Winter
# 21                           NaN               11  Winter
# 22                           NaN               21  Winter
# 23                           NaN                9  Winter
# 24                           NaN               40  Winter
# 25                           NaN               40  Winter
# 26                           NaN               21  Winter
# 27                           NaN               30  Winter
# 28                           NaN                6  Winter
# 29                           NaN               36  Winter
# ...                          ...              ...     ...
# 2631141                      NaN               41    Fall
# 2631142                      NaN               15    Fall
# 2631143                      NaN               21    Fall
# 2631144                      NaN               21    Fall
# 2631145                      NaN               36  Summer
# 2631146                      NaN                8    Fall
# 2631147                    106.0               33    Fall
# 2631148                     89.0               33    Fall
# 2631149                      NaN                8    Fall
# 2631150                      NaN               21    Fall
# 2631151                      NaN               15    Fall
# 2631152                      NaN               16    Fall
# 2631153                      NaN               36    Fall
# 2631154                      NaN               21    Fall
# 2631155                    117.0               33    Fall
# 2631156                     89.0               33  Summer
# 2631157                      NaN               21    Fall
# 2631158                      NaN               21    Fall
# 2631159                      NaN               21    Fall
# 2631160                     89.0               33    Fall
# 2631161                      NaN               21    Fall
# 2631162                      NaN               37    Fall
# 2631163                      NaN               21    Fall
# 2631164                      NaN               16    Fall
# 2631165                      NaN               27    Fall
# 2631166                      NaN               20    Fall
# 2631167                      NaN               21    Fall
# 2631168                     89.0               33    Fall
# 2631169                      NaN               21  Winter
# 2631170                    117.0               33  Spring
#
# [2389564 rows x 13 columns]

# %%
#Export as csv
year_2014_df_2.to_csv(r'03_Cleaned_Data\masterfile.csv', index = False)

# %%
#CARDIOVASCULAR DISEASE CODES 
#KEEP(214, 027, 053, 062, 18)

# %%
#Make a copy of this dataset to do analysis for specific diseases 
year_2014_df_3 = year_2014_df_2

# %%
# year_2014_df_3

# %%
#use iloc for those disease codes 
df214 = year_2014_df_3[year_2014_df_3.iloc[:, 8] == 214]
df27 = year_2014_df_3[year_2014_df_3.iloc[:, 8] == 27]
df53 = year_2014_df_3[year_2014_df_3.iloc[:, 8] == 53]
df62 = year_2014_df_3[year_2014_df_3.iloc[:, 8] == 62]
df18 = year_2014_df_3[year_2014_df_3.iloc[:, 8] == 18]
# print(df)

# %%
df1 = df214.copy()
df2 = df27.copy()
df3 = df53.copy()
df4 = df62.copy()
df5 = df18.copy()

cardio_df = pd.concat([df1, df2, df3, df4, df5])
cardio_df

#Export as csv
cardio_df.to_csv(r'03_Cleaned_Data\Cardiomortality.csv', index = True)

# %%
#CHILD DISEASE CODES
#Highest mortality of kids under 1 years old vs 1 year/2 year/3 year/ 4 year
child_disease_df = year_2014_df_2

# %%
child_disease_df = child_disease_df.dropna(subset=['age_recode_27'])
child_disease_df = child_disease_df.drop(columns=['day_of_week_of_death', 'education_2003_revision', 'infant_age_recode_22', 'marital_status', '358_cause_recode', '113_cause_recode', '39_cause_recode'])
child_disease_df
# Out:
#          month_of_death sex  detail_age  age_recode_27  \
# 0                     1   M          87             23
# 1                     1   M          58             17
# 2                     1   F          75             21
# 3                     1   M          74             20
# 4                     1   M          64             18
# 5                     1   F          93             24
# 6                     1   M          82             22
# 7                     1   M          55             17
# 8                     1   F          86             23
# 9                     1   M          23             10
# 10                    1   F          79             21
# 11                    1   M          86             23
# 12                    1   F          85             23
# 13                    1   F          84             22
# 14                    1   F          66             19
# 15                    1   F          70             20
# 16                    1   F          92             24
# 17                    1   F          82             22
# 18                    1   M          83             22
# 19                    1   F          84             22
# 20                    1   M          80             22
# 21                    1   M          66             19
# 22                    1   F          73             20
# 23                    1   F          51             16
# 24                    1   M          20             10
# 25                    1   M          45             15
# 26                    1   M          71             20
# 27                    1   F          46             15
# 28                    1   M          78             21
# 29                    1   M          72             20
# ...                 ...  ..         ...            ...
# 2631141              12   M          69             19
# 2631142              12   M          61             18
# 2631143              11   M          66             19
# 2631144              12   M          58             17
# 2631145               7   M          45             15
# 2631146              12   M          73             20
# 2631147              12   F          21              1
# 2631148              12   M           6              1
# 2631149              12   F          68             19
# 2631150              12   M          66             19
# 2631151              11   M          55             17
# 2631152              11   M          85             23
# 2631153              12   M          57             17
# 2631154              12   M          73             20
# 2631155              12   M           3              1
# 2631156               9   F           3              1
# 2631157              12   M          61             18
# 2631158              11   F          90             24
# 2631159              11   M          85             23
# 2631160              12   M           2              1
# 2631161              12   M          90             24
# 2631162              12   F          85             23
# 2631163              11   M          79             21
# 2631164              12   M          67             19
# 2631165              12   M          54             16
# 2631166              12   M          84             22
# 2631167              12   F          74             20
# 2631168              12   M           7              1
# 2631169               2   M          49             15
# 2631170               5   M          39              1
#
#          130_infant_cause_recode Seasons
# 0                            NaN  Winter
# 1                            NaN  Winter
# 2                            NaN  Winter
# 3                            NaN  Winter
# 4                            NaN  Winter
# 5                            NaN  Winter
# 6                            NaN  Winter
# 7                            NaN  Winter
# 8                            NaN  Winter
# 9                            NaN  Winter
# 10                           NaN  Winter
# 11                           NaN  Winter
# 12                           NaN  Winter
# 13                           NaN  Winter
# 14                           NaN  Winter
# 15                           NaN  Winter
# 16                           NaN  Winter
# 17                           NaN  Winter
# 18                           NaN  Winter
# 19                           NaN  Winter
# 20                           NaN  Winter
# 21                           NaN  Winter
# 22                           NaN  Winter
# 23                           NaN  Winter
# 24                           NaN  Winter
# 25                           NaN  Winter
# 26                           NaN  Winter
# 27                           NaN  Winter
# 28                           NaN  Winter
# 29                           NaN  Winter
# ...                          ...     ...
# 2631141                      NaN    Fall
# 2631142                      NaN    Fall
# 2631143                      NaN    Fall
# 2631144                      NaN    Fall
# 2631145                      NaN  Summer
# 2631146                      NaN    Fall
# 2631147                    106.0    Fall
# 2631148                     89.0    Fall
# 2631149                      NaN    Fall
# 2631150                      NaN    Fall
# 2631151                      NaN    Fall
# 2631152                      NaN    Fall
# 2631153                      NaN    Fall
# 2631154                      NaN    Fall
# 2631155                    117.0    Fall
# 2631156                     89.0  Summer
# 2631157                      NaN    Fall
# 2631158                      NaN    Fall
# 2631159                      NaN    Fall
# 2631160                     89.0    Fall
# 2631161                      NaN    Fall
# 2631162                      NaN    Fall
# 2631163                      NaN    Fall
# 2631164                      NaN    Fall
# 2631165                      NaN    Fall
# 2631166                      NaN    Fall
# 2631167                      NaN    Fall
# 2631168                     89.0    Fall
# 2631169                      NaN  Winter
# 2631170                    117.0  Spring
#
# [2389564 rows x 6 columns]

# %%
# Bin into age
size_bins = [0, 2, 3, 4, 5, 6, 27]
group_names = ["Under 1 Years Old", "1 Years Old", "2 Years Old", "3 Years Old", "4 Years Old", "NaN"]

# add season bins columns & row Labels
child_disease_df["InfantAge"] = pd.cut(child_disease_df["age_recode_27"], size_bins, labels=group_names)
child_disease_df["InfantAge"]
child_disease_df
# Out:
#          month_of_death sex  detail_age  age_recode_27  \
# 0                     1   M          87             23
# 1                     1   M          58             17
# 2                     1   F          75             21
# 3                     1   M          74             20
# 4                     1   M          64             18
# 5                     1   F          93             24
# 6                     1   M          82             22
# 7                     1   M          55             17
# 8                     1   F          86             23
# 9                     1   M          23             10
# 10                    1   F          79             21
# 11                    1   M          86             23
# 12                    1   F          85             23
# 13                    1   F          84             22
# 14                    1   F          66             19
# 15                    1   F          70             20
# 16                    1   F          92             24
# 17                    1   F          82             22
# 18                    1   M          83             22
# 19                    1   F          84             22
# 20                    1   M          80             22
# 21                    1   M          66             19
# 22                    1   F          73             20
# 23                    1   F          51             16
# 24                    1   M          20             10
# 25                    1   M          45             15
# 26                    1   M          71             20
# 27                    1   F          46             15
# 28                    1   M          78             21
# 29                    1   M          72             20
# ...                 ...  ..         ...            ...
# 2631141              12   M          69             19
# 2631142              12   M          61             18
# 2631143              11   M          66             19
# 2631144              12   M          58             17
# 2631145               7   M          45             15
# 2631146              12   M          73             20
# 2631147              12   F          21              1
# 2631148              12   M           6              1
# 2631149              12   F          68             19
# 2631150              12   M          66             19
# 2631151              11   M          55             17
# 2631152              11   M          85             23
# 2631153              12   M          57             17
# 2631154              12   M          73             20
# 2631155              12   M           3              1
# 2631156               9   F           3              1
# 2631157              12   M          61             18
# 2631158              11   F          90             24
# 2631159              11   M          85             23
# 2631160              12   M           2              1
# 2631161              12   M          90             24
# 2631162              12   F          85             23
# 2631163              11   M          79             21
# 2631164              12   M          67             19
# 2631165              12   M          54             16
# 2631166              12   M          84             22
# 2631167              12   F          74             20
# 2631168              12   M           7              1
# 2631169               2   M          49             15
# 2631170               5   M          39              1
#
#          130_infant_cause_recode Seasons          InfantAge
# 0                            NaN  Winter                NaN
# 1                            NaN  Winter                NaN
# 2                            NaN  Winter                NaN
# 3                            NaN  Winter                NaN
# 4                            NaN  Winter                NaN
# 5                            NaN  Winter                NaN
# 6                            NaN  Winter                NaN
# 7                            NaN  Winter                NaN
# 8                            NaN  Winter                NaN
# 9                            NaN  Winter                NaN
# 10                           NaN  Winter                NaN
# 11                           NaN  Winter                NaN
# 12                           NaN  Winter                NaN
# 13                           NaN  Winter                NaN
# 14                           NaN  Winter                NaN
# 15                           NaN  Winter                NaN
# 16                           NaN  Winter                NaN
# 17                           NaN  Winter                NaN
# 18                           NaN  Winter                NaN
# 19                           NaN  Winter                NaN
# 20                           NaN  Winter                NaN
# 21                           NaN  Winter                NaN
# 22                           NaN  Winter                NaN
# 23                           NaN  Winter                NaN
# 24                           NaN  Winter                NaN
# 25                           NaN  Winter                NaN
# 26                           NaN  Winter                NaN
# 27                           NaN  Winter                NaN
# 28                           NaN  Winter                NaN
# 29                           NaN  Winter                NaN
# ...                          ...     ...                ...
# 2631141                      NaN    Fall                NaN
# 2631142                      NaN    Fall                NaN
# 2631143                      NaN    Fall                NaN
# 2631144                      NaN    Fall                NaN
# 2631145                      NaN  Summer                NaN
# 2631146                      NaN    Fall                NaN
# 2631147                    106.0    Fall  Under 1 Years Old
# 2631148                     89.0    Fall  Under 1 Years Old
# 2631149                      NaN    Fall                NaN
# 2631150                      NaN    Fall                NaN
# 2631151                      NaN    Fall                NaN
# 2631152                      NaN    Fall                NaN
# 2631153                      NaN    Fall                NaN
# 2631154                      NaN    Fall                NaN
# 2631155                    117.0    Fall  Under 1 Years Old
# 2631156                     89.0  Summer  Under 1 Years Old
# 2631157                      NaN    Fall                NaN
# 2631158                      NaN    Fall                NaN
# 2631159                      NaN    Fall                NaN
# 2631160                     89.0    Fall  Under 1 Years Old
# 2631161                      NaN    Fall                NaN
# 2631162                      NaN    Fall                NaN
# 2631163                      NaN    Fall                NaN
# 2631164                      NaN    Fall                NaN
# 2631165                      NaN    Fall                NaN
# 2631166                      NaN    Fall                NaN
# 2631167                      NaN    Fall                NaN
# 2631168                     89.0    Fall  Under 1 Years Old
# 2631169                      NaN  Winter                NaN
# 2631170                    117.0  Spring  Under 1 Years Old
#
# [2389564 rows x 7 columns]

# %%
child_disease_df = child_disease_df.drop(child_disease_df[child_disease_df.InfantAge == "NaN"].index)

# %%
child_disease_df = child_disease_df.drop(columns=['detail_age', 'age_recode_27'])
child_disease_df

#Export to CSV
child_disease_df.to_csv(r'03_Cleaned_Data\childmortality.csv', index = True)

# %%
child_disease_df
# Out:
#          month_of_death sex  130_infant_cause_recode Seasons  \
# 190                   1   M                    110.0  Winter
# 214                   1   F                     98.0  Winter
# 215                   1   M                    115.0  Winter
# 216                   1   M                    108.0  Winter
# 244                   1   F                    136.0  Winter
# 295                   1   F                    136.0  Winter
# 604                   1   M                    135.0  Winter
# 627                   2   M                    135.0  Winter
# 666                   2   F                    108.0  Winter
# 667                   2   F                    136.0  Winter
# 716                   3   M                     84.0  Winter
# 719                   3   M                      NaN  Winter
# 777                   3   M                     76.0  Winter
# 799                   3   F                      NaN  Winter
# 819                   3   M                      NaN  Winter
# 914                   3   F                    135.0  Winter
# 946                   3   M                      NaN  Winter
# 947                   3   F                    106.0  Winter
# 972                   4   F                    135.0  Spring
# 1051                  4   F                    135.0  Spring
# 1105                  4   M                      NaN  Spring
# 1134                  3   M                      9.0  Winter
# 1146                  4   M                      NaN  Spring
# 1156                  5   F                      NaN  Spring
# 1201                  4   F                    106.0  Spring
# 1235                  4   M                     80.0  Spring
# 1252                  4   F                    117.0  Spring
# 1443                  5   M                    130.0  Spring
# 1465                  5   F                    106.0  Spring
# 1574                  6   F                     66.0  Spring
# ...                 ...  ..                      ...     ...
# 2629382              12   M                      NaN    Fall
# 2629427              12   M                     61.0    Fall
# 2629592              12   F                    136.0    Fall
# 2629620              12   F                     65.0    Fall
# 2629623              12   M                    106.0    Fall
# 2629648              12   M                    136.0    Fall
# 2629721              12   M                    117.0    Fall
# 2629782              11   F                      NaN    Fall
# 2629834              12   M                    155.0    Fall
# 2629900              12   M                     62.0    Fall
# 2629914              12   F                    128.0    Fall
# 2630152              12   M                     89.0    Fall
# 2630216              12   M                    117.0    Fall
# 2630388              12   M                      NaN    Fall
# 2630490              12   M                      NaN    Fall
# 2630492              12   F                     96.0    Fall
# 2630612              12   M                    136.0    Fall
# 2630753              12   F                    136.0    Fall
# 2630841              12   M                      NaN    Fall
# 2630873              12   F                     82.0    Fall
# 2630951              12   M                    117.0    Fall
# 2631003              10   F                    136.0    Fall
# 2631019              12   M                     89.0    Fall
# 2631147              12   F                    106.0    Fall
# 2631148              12   M                     89.0    Fall
# 2631155              12   M                    117.0    Fall
# 2631156               9   F                     89.0  Summer
# 2631160              12   M                     89.0    Fall
# 2631168              12   M                     89.0    Fall
# 2631170               5   M                    117.0  Spring
#
#                  InfantAge
# 190      Under 1 Years Old
# 214      Under 1 Years Old
# 215      Under 1 Years Old
# 216      Under 1 Years Old
# 244      Under 1 Years Old
# 295      Under 1 Years Old
# 604      Under 1 Years Old
# 627      Under 1 Years Old
# 666      Under 1 Years Old
# 667      Under 1 Years Old
# 716      Under 1 Years Old
# 719            4 Years Old
# 777      Under 1 Years Old
# 799            1 Years Old
# 819            4 Years Old
# 914      Under 1 Years Old
# 946            1 Years Old
# 947      Under 1 Years Old
# 972      Under 1 Years Old
# 1051     Under 1 Years Old
# 1105           1 Years Old
# 1134     Under 1 Years Old
# 1146           3 Years Old
# 1156           4 Years Old
# 1201     Under 1 Years Old
# 1235     Under 1 Years Old
# 1252     Under 1 Years Old
# 1443     Under 1 Years Old
# 1465     Under 1 Years Old
# 1574     Under 1 Years Old
# ...                    ...
# 2629382        4 Years Old
# 2629427  Under 1 Years Old
# 2629592  Under 1 Years Old
# 2629620  Under 1 Years Old
# 2629623  Under 1 Years Old
# 2629648  Under 1 Years Old
# 2629721  Under 1 Years Old
# 2629782        1 Years Old
# 2629834  Under 1 Years Old
# 2629900  Under 1 Years Old
# 2629914  Under 1 Years Old
# 2630152  Under 1 Years Old
# 2630216  Under 1 Years Old
# 2630388        3 Years Old
# 2630490        2 Years Old
# 2630492  Under 1 Years Old
# 2630612  Under 1 Years Old
# 2630753  Under 1 Years Old
# 2630841        1 Years Old
# 2630873  Under 1 Years Old
# 2630951  Under 1 Years Old
# 2631003  Under 1 Years Old
# 2631019  Under 1 Years Old
# 2631147  Under 1 Years Old
# 2631148  Under 1 Years Old
# 2631155  Under 1 Years Old
# 2631156  Under 1 Years Old
# 2631160  Under 1 Years Old
# 2631168  Under 1 Years Old
# 2631170  Under 1 Years Old
#
# [24724 rows x 5 columns]

# %%
#Seasonal Impact on Mortality 
#Respitory = KEEP(247, 248, 251, 252, 258, 260, 261, 262, 276, 278, 361, 362, 371, 13, 90, 95)
#Circulatory = KEEP(197, 244, 246, 370)

# %%
#copy cleaned up dataframe to run specific analysis
seasons_df = year_2014_df_2

# %%
#Drop irrelavent columns
seasons_df = seasons_df.drop(columns=['education_2003_revision', 'month_of_death', 'sex', 'detail_age', 'age_recode_27', 'infant_age_recode_22', 'marital_status', 'day_of_week_of_death', '39_cause_recode'])
seasons_df
# Out:
#          358_cause_recode  113_cause_recode  130_infant_cause_recode Seasons
# 0                     238                70                      NaN  Winter
# 1                     214                62                      NaN  Winter
# 2                     267                86                      NaN  Winter
# 3                     228                68                      NaN  Winter
# 4                     214                62                      NaN  Winter
# 5                     280               111                      NaN  Winter
# 6                     215                63                      NaN  Winter
# 7                     214                62                      NaN  Winter
# 8                     175               111                      NaN  Winter
# 9                     429               125                      NaN  Winter
# 10                    225                68                      NaN  Winter
# 11                    188                51                      NaN  Winter
# 12                    225                68                      NaN  Winter
# 13                     93                27                      NaN  Winter
# 14                     93                27                      NaN  Winter
# 15                    215                63                      NaN  Winter
# 16                    228                68                      NaN  Winter
# 17                    215                63                      NaN  Winter
# 18                    267                86                      NaN  Winter
# 19                    129                39                      NaN  Winter
# 20                    215                63                      NaN  Winter
# 21                    113                33                      NaN  Winter
# 22                    211                59                      NaN  Winter
# 23                    104                29                      NaN  Winter
# 24                    429               125                      NaN  Winter
# 25                    429               125                      NaN  Winter
# 26                    211                59                      NaN  Winter
# 27                    298                94                      NaN  Winter
# 28                     81                23                      NaN  Winter
# 29                    379               110                      NaN  Winter
# ...                   ...               ...                      ...     ...
# 2631141               436               129                      NaN    Fall
# 2631142                77                21                      NaN    Fall
# 2631143               211                59                      NaN    Fall
# 2631144               214                62                      NaN    Fall
# 2631145               379               110                      NaN  Summer
# 2631146                93                27                      NaN    Fall
# 2631147               363               108                    106.0    Fall
# 2631148               358               108                     89.0    Fall
# 2631149                93                27                      NaN    Fall
# 2631150               214                62                      NaN    Fall
# 2631151               122                36                      NaN    Fall
# 2631152               159                46                      NaN    Fall
# 2631153               379               110                      NaN    Fall
# 2631154               215                63                      NaN    Fall
# 2631155               364               108                    117.0    Fall
# 2631156               358               108                     89.0  Summer
# 2631157               215                63                      NaN    Fall
# 2631158               215                63                      NaN    Fall
# 2631159               215                63                      NaN    Fall
# 2631160               358               108                     89.0    Fall
# 2631161               215                63                      NaN    Fall
# 2631162               175               111                      NaN    Fall
# 2631163               215                63                      NaN    Fall
# 2631164               159                46                      NaN    Fall
# 2631165               257                78                      NaN    Fall
# 2631166               207                56                      NaN    Fall
# 2631167               215                63                      NaN    Fall
# 2631168               358               108                     89.0    Fall
# 2631169               214                62                      NaN  Winter
# 2631170               364               108                    117.0  Spring
#
# [2389564 rows x 4 columns]

# %%
#Respitory = KEEP(247, 248, 251, 252, 258, 260, 261, 262, 276, 278, 361, 362, 371, 13, 90, 95)
#use iloc for respitory disease codes 
df251 = seasons_df[seasons_df.iloc[:, 0] == 251]
df260 = seasons_df[seasons_df.iloc[:, 0] == 260]
df261 = seasons_df[seasons_df.iloc[:, 0] == 261]
df276 = seasons_df[seasons_df.iloc[:, 0] == 276]
df278 = seasons_df[seasons_df.iloc[:, 0] == 278]
df361 = seasons_df[seasons_df.iloc[:, 0] == 361]
df362 = seasons_df[seasons_df.iloc[:, 0] == 362]
df371 = seasons_df[seasons_df.iloc[:, 0] == 371]
df13 = seasons_df[seasons_df.iloc[:, 0] == 13]
df95 = seasons_df[seasons_df.iloc[:, 0] == 95]

#Dropped several disease codes because no records
#Concact into one datafram for respitory diseases
respiratory_df = pd.concat([df251, df260, df261, df276, df278, df361, df362, df371, df13, df95])
respiratory_df

#Export to CSV
respiratory_df.to_csv(r'03_Cleaned_Data\respiratorymortality.csv', index = True)

# %%
#Circulatory = KEEP(197, 244, 246, 370)
#use iloc for circulatory disease codes 
df246 = seasons_df[seasons_df.iloc[:, 0] == 246]
df370 = seasons_df[seasons_df.iloc[:, 0] == 370]

#Dropped 197 & 244 because there were no records 
#Concact into one datafram for respitory diseases
circulatory_df = pd.concat([df246, df370])
circulatory_df

#Export to CSV
circulatory_df.to_csv(r'03_Cleaned_Data\circulatorymortality.csv', index = True)

# %%
#College Education on Mortality.

# %%
college_df = year_2014_df_2

# %%
college_df = college_df.drop(columns=['130_infant_cause_recode', 'month_of_death', 'sex', 'detail_age',  'infant_age_recode_22', 'marital_status', 'day_of_week_of_death', '39_cause_recode', 'Seasons'])

# %%
college_df

#Export to CSV
college_df.to_csv(r'03_Cleaned_Data\collegemortality.csv', index = True)
