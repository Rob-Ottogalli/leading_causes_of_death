# %%
import pandas as pd
import json
import numpy as np

# %%
year_2013_df = pd.read_csv('01_Raw_Data/28_3144_compressed_2013_data.csv/2013_data.csv')
with open("01_Raw_Data/2013_codes.json", "r") as f_open:
    code_maps_2013 = json.load(f_open)
# year_2014_df = pd.read_csv('01_Raw_Data/28_3144_compressed_2014_data.csv/2014_data.csv')
# year_2015_df = pd.read_csv('01_Raw_Data/28_3144_compressed_2015_data.csv/2015_data.csv')
# Out:
# C:\Users\Rob-Desktop\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (39,40,41,42,43,60,61,62,63,64,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(year_2013_df['358_cause_recode'].mode()[0])
# Out:
# 215

# %%
year_2013_df['decoded_358_cause'] = year_2013_df['358_cause_recode'].apply(
    lambda x: code_maps_2013['358_cause_recode']["175"])

# %%
print(year_2013_df['decoded_358_cause'].mode()[0])
# Out:
# Organic dementia (F01,F03)

# %%
print(year_2013_df['month_of_death'].mode()[0])
# Out:
# 1

# %%
year_2013_df['month_of_death'] = year_2013_df['month_of_death'].apply(
    lambda x: code_maps_2013['month_of_death'][x])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-4aa810b13f39> in <module>
#       1 year_2013_df['month_of_death'] = year_2013_df['month_of_death'].apply(
# ----> 2     lambda x: code_maps_2013['month_of_death'][x])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-7-4aa810b13f39> in <lambda>(x)
#       1 year_2013_df['month_of_death'] = year_2013_df['month_of_death'].apply(
# ----> 2     lambda x: code_maps_2013['month_of_death'][x])
#
# KeyError: 1

# %%
print(year_2013_df['month_of_death'].mode()[0])
# Out:
# 1

# %%
print(code_maps_2013["358_cause_recode"]["159"])
# Out:
# Diabetes mellitus (E10-E14)

# %%
year_2013_df.dtypes
# Out:
# resident_status                                             int64
# education_1989_revision                                   float64
# education_2003_revision                                   float64
# education_reporting_flag                                    int64
# month_of_death                                              int64
# sex                                                        object
# detail_age_type                                             int64
# detail_age                                                  int64
# age_substitution_flag                                     float64
# age_recode_52                                               int64
# age_recode_27                                               int64
# age_recode_12                                               int64
# infant_age_recode_22                                      float64
# place_of_death_and_decedents_status                         int64
# ...

# %%
year_2013_df['358_cause_recode'] = year_2013_df['358_cause_recode'].astype(dtype=np.int64)

# %%
year_2013_df.head(25)
# Out:
#     resident_status  education_1989_revision  education_2003_revision  \
# 0                 1                     15.0                      NaN
# 1                 1                     12.0                      NaN
# 2                 2                     17.0                      NaN
# 3                 1                     99.0                      NaN
# 4                 1                     12.0                      NaN
# 5                 2                     12.0                      NaN
# 6                 1                     16.0                      NaN
# 7                 1                     13.0                      NaN
# 8                 1                     17.0                      NaN
# 9                 2                     12.0                      NaN
# 10                1                     12.0                      NaN
# 11                2                     16.0                      NaN
# ...

# %%
year_2014_df.head()

# %%
year_2015_df.head()
